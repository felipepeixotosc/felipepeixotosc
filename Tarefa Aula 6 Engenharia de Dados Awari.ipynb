# %% [markdown]
# ## Instalando bibliotecas

# %%
# !pip install pandas
# !pip install pymongo
# !pip install boto3

# %% [markdown]
# ## Importando bibliotecas

# %%
import numpy as np
import pandas as pd
from io import BytesIO
from pymongo import MongoClient
import boto3
from io import StringIO

# %% [markdown]
# ## MINIO

# %%
client = boto3.client('s3', 
    endpoint_url='http://awari-minio-nginx:9000',
    aws_access_key_id='IHTSThvVQZYLnYJK',
    aws_secret_access_key='YlC0CPdqGIQZTUDtFG0ah7cdQbIoHRnv',
    aws_session_token=None,
    config=boto3.session.Config(signature_version='s3v4'),
    verify=False,
    region_name='sa-east-1'
)

# %%
# Salvando data set organizando por pastas no Minio

estados = pd.read_csv('arquivos/estados.csv')

estados
# Out:
#     codigo_uf  uf                 nome  latitude  longitude        regiao
# 0          11  RO             Rondônia    -10.83     -63.34         Norte
# 1          12  AC                 Acre     -8.77     -70.55         Norte
# 2          13  AM             Amazonas     -3.47     -65.10         Norte
# 3          14  RR              Roraima      1.99     -61.33         Norte
# 4          15  PA                 Pará     -3.79     -52.48         Norte
# 5          16  AP                Amapá      1.41     -51.77         Norte
# 6          17  TO            Tocantins     -9.46     -48.26         Norte
# 7          21  MA             Maranhão     -5.42     -45.44      Nordeste
# 8          22  PI                Piauí     -6.60     -42.28      Nordeste
# 9          23  CE                Ceará     -5.20     -39.53      Nordeste
# 10         24  RN  Rio Grande do Norte     -5.81     -36.59      Nordeste
# 11         25  PB              Paraíba     -7.28     -36.72      Nordeste
# ...

# %%
# Salvando data set organizando por pastas no Minio

municipios = pd.read_csv('arquivos/municipios.csv')

municipios
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf  siafi_id  ddd       fuso_horario
# 0            52      1050   62  America/Sao_Paulo
# ...

# %%
cidades = pd.merge(municipios,estados[['codigo_uf','uf']] , on='codigo_uf', how='left')
cidades
# Out:
#       codigo_ibge                 nome  latitude  longitude  capital  \
# 0         5200050      Abadia de Goiás -16.75730   -49.4412        0
# 1         3100104  Abadia dos Dourados -18.48310   -47.3916        0
# 2         5200100            Abadiânia -16.19700   -48.7057        0
# 3         3100203               Abaeté -19.15510   -45.4444        0
# 4         1500107           Abaetetuba  -1.72183   -48.8788        0
# ...           ...                  ...       ...        ...      ...
# 5565      2933604          Xique-Xique -10.82300   -42.7245        0
# 5566      2517407               Zabelê  -8.07901   -37.1057        0
# 5567      3557154             Zacarias -21.05060   -50.0552        0
# 5568      2114007              Zé Doca  -3.27014   -45.6553        0
# 5569      4219853               Zortéa -27.45210   -51.5520        0
#
#       codigo_uf  siafi_id  ddd       fuso_horario  uf
# 0            52      1050   62  America/Sao_Paulo  GO
# ...

# %%
cidades = cidades.fillna("-") # Nós precisamos atrelar o resultado a variavel principal
ufs = cidades['uf'].drop_duplicates()
ufs
# Out:
# 0      GO
# 1      MG
# 4      PA
# 5      CE
# 6      BA
# 8      PR
# 9      SC
# 13     PE
# 14     TO
# 16     MA
# 21     RN
# 22     PI
# 23     RS
# 25     MT
# 26     AC
# 30     SP
# 37     ES
# 49     PB
# 50     AL
# 51     MS
# 131    RO
# 141    RR
# 170    AM
# 186    AP
# 207    SE
# 242    RJ
# 755    DF
# Name: uf, dtype: object

# %%
for row in ufs:
    df_by_ufs = df.query("uf == '" + row + "'")
    
    if row == "-":
        folder_name = 'empty'
    else:
        folder_name = row
        
    csv_buffer = StringIO()    
    csv = df_by_gender.to_csv(csv_buffer)
    client.put_object(Body=csv_buffer.getvalue(), Bucket='aula-06', Key=f'datalake/gender/{folder_name}/{folder_name}.csv')
